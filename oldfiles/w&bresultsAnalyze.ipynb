# %%
import pandas as pd
import seaborn as sns

# %%
gd0=pd.read_csv("./w&bresults/509_datasets_487/groundtruth0.csv")

# %%
gd0.head()
# Out:
#    Unnamed: 0  loss_LA_pear  _step  dataset  loss_LA_p  loss_LA_nlcor  \
# 0           0     -0.131854      0        0        0.0       0.131854
# 1           1     -0.154941      1        1        0.0       0.154941
# 2           2      0.540900      3        3        0.0       0.540900
# 3           3     -0.503055      4        4        0.0       0.503055
# 4           4     -0.211853      5        5        0.0       0.211853
#
#    _runtime  loss_LB_p  loss_LA_spear  loss_LB_pear  loss_LB_nlcor  \
# 0       398       0.24      -0.129201     -0.052812       0.052812
# 1       788       0.67      -0.155228     -0.014244       0.092037
# 2      1568       0.68       0.563343      0.029038       0.050133
# 3      1956       0.12      -0.519556     -0.054573       0.054573
# 4      2347       0.88      -0.209376      0.010935       0.100236
#
#    loss_LB_spear  loss_LA_mutual  loss_LB_mutual  _timestamp   true_LA  \
# ...

# %%
gd1=pd.read_csv("./w&bresults/509_datasets_487/groundtruth1.csv")

# %%
gd0_modified=gd0.drop(['Unnamed: 0','_runtime','_step', 'dataset','_timestamp'],1)
# Out:
# /tmp/ipykernel_256365/427612420.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   gd0_modified=gd0.drop(['Unnamed: 0','_runtime','_step', 'dataset','_timestamp'],1)

# %%
gd0_modified_LA=gd0_modified.drop(['loss_LB_pear', 'loss_LB_nlcor','loss_LB_spear','loss_LB_mutual','true_LB'],1)
# Out:
# /tmp/ipykernel_256365/1274858699.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   gd0_modified_LA=gd0_modified.drop(['loss_LB_pear', 'loss_LB_nlcor','loss_LB_spear','loss_LB_mutual','true_LB'],1)

# %%
gd0_modified_LB=gd0_modified.drop(['loss_LA_pear', 'loss_LA_nlcor','loss_LA_spear','loss_LA_mutual','true_LA'],1)
# Out:
# /tmp/ipykernel_256365/1096693578.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   gd0_modified_LB=gd0_modified.drop(['loss_LA_pear', 'loss_LA_nlcor','loss_LA_spear','loss_LA_mutual','true_LA'],1)

# %%
gd1_modified=gd1.drop(['Unnamed: 0','_runtime','_step', 'dataset','_timestamp'],1)
gd1_modified_LA=gd1_modified.drop(['loss_LB_pear', 'loss_LB_nlcor','loss_LB_spear','loss_LB_mutual','true_LB'],1)
gd1_modified_LB=gd1_modified.drop(['loss_LA_pear', 'loss_LA_nlcor','loss_LA_spear','loss_LA_mutual','true_LA'],1)
# Out:
# /tmp/ipykernel_256365/2481364704.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   gd1_modified=gd1.drop(['Unnamed: 0','_runtime','_step', 'dataset','_timestamp'],1)
# /tmp/ipykernel_256365/2481364704.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   gd1_modified_LA=gd1_modified.drop(['loss_LB_pear', 'loss_LB_nlcor','loss_LB_spear','loss_LB_mutual','true_LB'],1)
# /tmp/ipykernel_256365/2481364704.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   gd1_modified_LB=gd1_modified.drop(['loss_LA_pear', 'loss_LA_nlcor','loss_LA_spear','loss_LA_mutual','true_LA'],1)

# %%
g = sns.pairplot(gd0_modified_LA)
g.fig.suptitle("L->A correlation using different techniques for groundtruth 0 ",y=1) #LA loss for gndtruth 0
# Out:
# Text(0.5, 1, 'L->A correlation using different techniques for groundtruth 0 ')

# %%
g=sns.pairplot(gd0_modified_LB) #LB loss plots
g.fig.suptitle("L->B correlation using different techniques for groundtruth 0 ",y=1)
# Out:
# Text(0.5, 1, 'L->B correlation using different techniques for groundtruth 0 ')

# %%
g=sns.pairplot(gd1_modified_LA)
g.fig.suptitle("L->A correlation using different techniques for groundtruth 1",y=1)
# Out:
# Text(0.5, 1, 'L->A correlation using different techniques for groundtruth 1')

# %%
g=sns.pairplot(gd1_modified_LB)
g.fig.suptitle("L->B correlation using different techniques for groundtruth 1",y=1)
# Out:
# Text(0.5, 1, 'L->B correlation using different techniques for groundtruth 1')
