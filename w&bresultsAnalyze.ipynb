# %%
import pandas as pd
import seaborn as sns

# %%
gd0=pd.read_csv("./w&bresults/groundtruth0.csv")

# %%
gd0.head()
# Out:
#    Unnamed: 0  loss_LA_pear  _step  dataset  loss_LA_p  loss_LA_nlcor  \
# 0           0     -0.131854      0        0       0.00       0.131854
# 1           1     -0.154941      1        1       0.00       0.154941
# 2           2      0.227137      2        2       0.87       0.227137
# 3           3      0.540900      3        3       0.00       0.540900
# 4           4     -0.503055      4        4       0.00       0.503055
#
#    _runtime  loss_LB_p  loss_LA_spear  loss_LB_pear  loss_LB_nlcor  \
# 0       398       0.24      -0.129201     -0.052812       0.052812
# 1       788       0.67      -0.155228     -0.014244       0.092037
# 2      1179       0.61       0.192485     -0.029303       0.154320
# 3      1568       0.68       0.563343      0.029038       0.050133
# 4      1956       0.12      -0.519556     -0.054573       0.054573
#
#    loss_LB_spear  loss_LA_mutual  loss_LB_mutual  _timestamp   true_LA  \
# 0      -0.047730        0.000000        0.002547  1646661510 -0.082740
# 1      -0.006136        0.012903        0.010678  1646661900  1.063246
# 2      -0.027857        0.037725        0.000000  1646662291  1.374717
# 3       0.030192        0.176253        0.000000  1646662680  0.103753
# 4      -0.066956        0.151217        0.034208  1646663068 -0.062840
#
#     true_LB
# 0 -0.233427
# 1 -0.370857
# 2 -0.298502
# 3  0.475246
# 4  0.629800

# %%
gd1=pd.read_csv("./w&bresults/groundtruth1.csv")

# %%
gd0_modified=gd0.drop(['Unnamed: 0','_runtime','_step', 'dataset','_timestamp'],1)
# Out:
# /tmp/ipykernel_134926/427612420.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   gd0_modified=gd0.drop(['Unnamed: 0','_runtime','_step', 'dataset','_timestamp'],1)

# %%
gd0_modified_LA=gd0_modified.drop(['loss_LB_pear', 'loss_LB_nlcor','loss_LB_spear','loss_LB_mutual','true_LB'],1)
# Out:
# /tmp/ipykernel_134926/1274858699.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   gd0_modified_LA=gd0_modified.drop(['loss_LB_pear', 'loss_LB_nlcor','loss_LB_spear','loss_LB_mutual','true_LB'],1)

# %%
gd0_modified_LB=gd0_modified.drop(['loss_LA_pear', 'loss_LA_nlcor','loss_LA_spear','loss_LA_mutual','true_LA'],1)
# Out:
# /tmp/ipykernel_134926/1096693578.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   gd0_modified_LB=gd0_modified.drop(['loss_LA_pear', 'loss_LA_nlcor','loss_LA_spear','loss_LA_mutual','true_LA'],1)

# %%
gd1_modified=gd0.drop(['Unnamed: 0','_runtime','_step', 'dataset','_timestamp'],1)
gd1_modified_LA=gd1_modified.drop(['loss_LB_pear', 'loss_LB_nlcor','loss_LB_spear','loss_LB_mutual','true_LB'],1)
gd1_modified_LB=gd1_modified.drop(['loss_LA_pear', 'loss_LA_nlcor','loss_LA_spear','loss_LA_mutual','true_LA'],1)
# Out:
# /tmp/ipykernel_134926/2013447331.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   gd1_modified=gd0.drop(['Unnamed: 0','_runtime','_step', 'dataset','_timestamp'],1)
# /tmp/ipykernel_134926/2013447331.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   gd1_modified_LA=gd1_modified.drop(['loss_LB_pear', 'loss_LB_nlcor','loss_LB_spear','loss_LB_mutual','true_LB'],1)
# /tmp/ipykernel_134926/2013447331.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   gd1_modified_LB=gd1_modified.drop(['loss_LA_pear', 'loss_LA_nlcor','loss_LA_spear','loss_LA_mutual','true_LA'],1)

# %%
sns.pairplot(gd0_modified_LA) #LA loss plots

# %%
sns.pairplot(gd0_modified_LA) #LB loss plots

# %%
sns.pairplot(gd1_modified_LA)

# %%
sns.pairplot(gd1_modified_LB)
