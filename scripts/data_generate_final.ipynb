# %%
import numpy as np 
import itertools
from scipy import signal
import sys

# %%
def generatelinear(n,outputname,sample_seed=None):
   '''
   Function to generate the linear data 
   n is the sample size 
   '''
   f = open(outputname, "w")
   if(sample_seed==None):
      rng = np.random.default_rng()
      sample_seed = rng.integers(sys.maxsize) 
   rng=np.random.default_rng(sample_seed)
    
   sample_seed1 = rng.integers(2**32 - 1)
   np.random.seed(sample_seed1)
   f.write("Seed "+ str(sample_seed))
   f.write("\n")
   beta1=[0.1,0.5,1,1.5,2,2.5,3,4,5,6]
   beta2=[0.1,0.5,1,1.5,2,2.5,3,4,5,6]
   for i in itertools.product(beta1,beta2):
      b1,b2=i
      L=np.random.binomial(1,0.5,n)
      A=b1*L+np.random.normal(0,1,n)
      B=b2*A+np.random.normal(0,1,n)
      f.write(str(b1)+" "+ str(b2))
      f.write("\n")
      np.savetxt(f,L,newline=' ',fmt='%s')
      f.write("\n")
      np.savetxt(f,A,newline=' ',fmt='%s')
      f.write("\n")
      np.savetxt(f,B,newline=' ',fmt='%s')
      f.write("\n")
   f.close()

# %%
def generateind(n,outputname,sample_seed=None):
   '''
   Function to generate the indpendent data 
   n is the sample size 
   '''
   f = open(outputname, "w")
   if(sample_seed==None):
      rng = np.random.default_rng()
      sample_seed = rng.integers(sys.maxsize) 
   rng=np.random.default_rng(sample_seed)
    
   sample_seed1 = rng.integers(2**32 - 1)
   np.random.seed(sample_seed1)
   f.write("Seed "+ str(sample_seed))

   f.write("\n")
   

   beta1=[0.1,0.5,1,1.5,2,2.5,3,4,5,6]
   beta2=[0.1,0.5,1,1.5,2,2.5,3,4,5,6]
   for i in itertools.product(beta1,beta2):
      b1,b2=i
      L=np.random.binomial(1,0.5,n)
      A=b1*L+np.random.normal(0,1,n)
      B=b2*L+np.random.normal(0,1,n)
      f.write(str(b1)+" "+ str(b2))
      f.write("\n")
      np.savetxt(f,L,newline=' ',fmt='%s')
      f.write("\n")
      np.savetxt(f,A,newline=' ',fmt='%s')
      f.write("\n")
      np.savetxt(f,B,newline=' ',fmt='%s')
      f.write("\n")
   f.close()

# %%
def generatesine(n,outputname,sample_seed=None):
   '''
   Function to generate the sine data 
   n is the sample size 
   '''
   f = open(outputname, "w")
   if(sample_seed==None):
      rng = np.random.default_rng()
      sample_seed = rng.integers(sys.maxsize) 
   rng=np.random.default_rng(sample_seed)
    
   sample_seed1 = rng.integers(2**32 - 1)
   np.random.seed(sample_seed1)
   f.write("Seed "+ str(sample_seed))
   f.write("\n")

   sigma1=[0.2,0.4,0.6,0.8,1]
   mu2=[0.1,0.5,1,1.5,2,2.5,3,4,5,6]
   sigma2=[0.5,1]
   for i in itertools.product(mu2,sigma1,sigma2):
      m2,s1,s2=i
      L=np.random.binomial(1,0.5,n)
      A=m2*L + np.random.normal(0,1,n)
      B=np.sin(2 * np.pi * (1/(8*s1)) * (A)- (np.pi/2 ))+np.random.normal(0,s2,n)
      f.write(str(m2)+" "+ str(s1)+" "+str(s2)+" ")
      f.write("\n")
      np.savetxt(f,L,newline=' ',fmt='%s')
      f.write("\n")
      np.savetxt(f,A,newline=' ',fmt='%s')
      f.write("\n")
      np.savetxt(f,B,newline=' ',fmt='%s')
      f.write("\n")
   f.close()

# %%
def generatesaw(n,outputname,sample_seed=None):
   '''
   Function to generate the sawtooth data 
   n is the sample size 
   '''
  
   f = open(outputname, "w")
   if(sample_seed==None):
      rng = np.random.default_rng()
      sample_seed = rng.integers(sys.maxsize) 
   rng=np.random.default_rng(sample_seed)
    
   sample_seed1 = rng.integers(2**32 - 1)
   np.random.seed(sample_seed1)
   f.write("Seed "+ str(sample_seed))
   f.write("\n")
   sigma1=[0.2,0.4,0.6,0.8,1]
   mu2=[0.1,0.5,1,1.5,2,2.5,3,4,5,6]
   sigma2=[0.5,1]
   for i in itertools.product(mu2,sigma1,sigma2):
      m2,s1,s2=i
      L=np.random.binomial(1,0.5,n)
      A=m2*L + np.random.normal(0,1,n)
      B=signal.sawtooth(2 * np.pi * (1/(8*s1)) * (A)- (np.pi/2 ))+np.random.normal(0,s2,n)
      f.write(str(m2)+" "+ str(s1)+" "+str(s2)+" ")
      f.write("\n")
      np.savetxt(f,L,newline=' ',fmt='%s')
      f.write("\n")
      np.savetxt(f,A,newline=' ',fmt='%s')
      f.write("\n")
      np.savetxt(f,B,newline=' ',fmt='%s')
      f.write("\n")
   f.close()

# %%
def generateparabola(n,outputname,sample_seed=None):
   '''
   Function to generate the linear data 
   n is the sample size 
   '''
   f = open(outputname, "w")
   if(sample_seed==None):
      rng = np.random.default_rng()
      sample_seed = rng.integers(sys.maxsize) 
   rng=np.random.default_rng(sample_seed)
    
   sample_seed1 = rng.integers(2**32 - 1)
   np.random.seed(sample_seed1)
   f.write("Seed "+ str(sample_seed))
   f.write("\n")
   beta1=[0.1,0.5,1,1.5,2,2.5,3,4,5,6]
   beta2=[0.1,0.5,1,1.5,2,2.5,3,4,5,6]
   for i in itertools.product(beta1,beta2):
      b1,b2=i
      L=np.random.binomial(1,0.5,n)
      A=b1*L+np.random.normal(0,1,n)
      B=b2*(A**2)+np.random.normal(0,1,n)
      f.write(str(b1)+" "+ str(b2))
      f.write("\n")
      np.savetxt(f,L,newline=' ',fmt='%s')
      f.write("\n")
      np.savetxt(f,A,newline=' ',fmt='%s')
      f.write("\n")
      np.savetxt(f,B,newline=' ',fmt='%s')
      f.write("\n")
   f.close()

# %%
def generateparabolavar(n,outputname,sample_seed=None):
   '''
   Function to generate the linear data 
   n is the sample size 
   '''
   f = open(outputname, "w")
   if(sample_seed==None):
      rng = np.random.default_rng()
      sample_seed = rng.integers(sys.maxsize) 
   rng=np.random.default_rng(sample_seed)
    
   sample_seed1 = rng.integers(2**32 - 1)
   np.random.seed(sample_seed1)
   f.write("Seed "+ str(sample_seed))
   f.write("\n")
   beta1=[1,2,3,4,5]
   beta2=[1,2,3,4,5]
   amps=[1,2,3,4]
   for i in itertools.product(beta1,beta2,amps):
      b1,b2,a=i
      L=np.random.binomial(1,0.5,n)
      A=a*L+ L*np.random.normal(0,b1,n)+(1-L)*np.random.normal(0,b2,n)
      B=(A**2)+np.random.normal(0,1,n) # Parabola unequal variance 
      f.write(str(b1)+" "+ str(b2)+" " + str(a))
      f.write("\n")
      np.savetxt(f,L,newline=' ',fmt='%s')
      f.write("\n")
      np.savetxt(f,A,newline=' ',fmt='%s')
      f.write("\n")
      np.savetxt(f,B,newline=' ',fmt='%s')
      f.write("\n")
   f.close()

# %%
def generatelinearvar(n,outputname,sample_seed=None):
   '''
   Function to generate the linear data 
   n is the sample size 
   '''
   f = open(outputname, "w")
   if(sample_seed==None):
      rng = np.random.default_rng()
      sample_seed = rng.integers(sys.maxsize) 
   rng=np.random.default_rng(sample_seed)
    
   sample_seed1 = rng.integers(2**32 - 1)
   np.random.seed(sample_seed1)
   f.write("Seed "+ str(sample_seed))
   f.write("\n")
   beta1=[1,2,3,4,5]
   beta2=[1,2,3,4,5]
   amps=[1,2,3,4]
   for i in itertools.product(beta1,beta2,amps):
      b1,b2,a=i
      L=np.random.binomial(1,0.5,n)
      A=a*L+ L*np.random.normal(0,b1,n)+(1-L)*np.random.normal(0,b2,n)
      B=(A)+np.random.normal(0,1,n) # Linear unequal variance 
      f.write(str(b1)+" "+ str(b2)+" " + str(a))
      f.write("\n")
      np.savetxt(f,L,newline=' ',fmt='%s')
      f.write("\n")
      np.savetxt(f,A,newline=' ',fmt='%s')
      f.write("\n")
      np.savetxt(f,B,newline=' ',fmt='%s')
      f.write("\n")
   f.close()

# %%
generatesaw(1000,outputname="dummycheck1.txt") # to generate the linear dataset with 1000 samples, pass the seed newseed argument to reproduce the result

# %%
generatesaw(1000,outputname="dummycheck2.txt",sample_seed=4000370289086976611)

# %%
#done
# generatelinear(1000,outputname='./simulation_final/data/Linear1000.txt')
# generateind(1000,outputname='./simulation_final/data/Indp1000.txt')
# generatesine(1000,outputname='./simulation_final/data/Sine1000.txt')
# generatesaw(1000,outputname='./simulation_final/data/Saw1000.txt')
# generatelinear(500,outputname='./simulation_final/data/Linear500.txt')
# generateind(500,outputname='./simulation_final/data/Indp500.txt')
# generatesine(500,outputname='./simulation_final/data/Sine500.txt')
# generatesaw(500,outputname='./simulation_final/data/Saw500.txt')
# generatelinear(300,outputname='./simulation_final/data/Linear300.txt')
# generateind(300,outputname='./simulation_final/data/Indp300.txt')
# generatesine(300,outputname='./simulation_final/data/Sine300.txt')
# generatesaw(300,outputname='./simulation_final/data/Saw300.txt')

# %%
#testing # seed testing passed 
generatelinear(1000,outputname='./simulation_final/data/test/Linear1000.txt',sample_seed=3586939475498222224)
generateind(1000,outputname='./simulation_final/data/test/Indp1000.txt',sample_seed=8202927200450957378)
generatesine(1000,outputname='./simulation_final/data/test/Sine1000.txt',sample_seed=2060614054273649201)
generatesaw(1000,outputname='./simulation_final/data/test/Saw1000.txt',sample_seed= 3718702057624586219)
generatelinear(500,outputname='./simulation_final/data/test/Linear500.txt',sample_seed=8195244996780620718)
generateind(500,outputname='./simulation_final/data/test/Indp500.txt',sample_seed= 6171446892837840330)
generatesine(500,outputname='./simulation_final/data/test/Sine500.txt',sample_seed= 2219779994047432601)
generatesaw(500,outputname='./simulation_final/data/test/Saw500.txt',sample_seed= 6707114236743860935)
generatelinear(300,outputname='./simulation_final/data/test/Linear300.txt',sample_seed=6548891165010411533)
generateind(300,outputname='./simulation_final/data/test/Indp300.txt',sample_seed= 4823185546808146148)
generatesine(300,outputname='./simulation_final/data/test/Sine300.txt',sample_seed=8097779890928020218)
generatesaw(300,outputname='./simulation_final/data/test/Saw300.txt',sample_seed=8662046133972514150)

# %%
#done 
# generateparabola(1000,outputname='./simulation_final/data/Para1000.txt')
# generateparabola(500,outputname='./simulation_final/data/Para500.txt')
# generateparabola(300,outputname='./simulation_final/data/Para300.txt')

# %%
#testing #testing passed 
generateparabola(1000,outputname='./simulation_final/data/test/Para1000.txt',sample_seed= 7886530859723877523)
generateparabola(500,outputname='./simulation_final/data/test/Para500.txt', sample_seed=282892347675383455)
generateparabola(300,outputname='./simulation_final/data/test/Para300.txt',sample_seed=4891253915387393228)

# %%
# done
# generateparabolavar(1000,outputname='./simulation_final/data/Paravar1000.txt')
# generateparabolavar(500,outputname='./simulation_final/data/Paravar500.txt')
# generateparabolavar(300,outputname='./simulation_final/data/Paravar300.txt')

# %%
# testing done # passed 
generateparabolavar(1000,outputname='./simulation_final/data/test/Paravar1000.txt', sample_seed=6604827719444576483)
generateparabolavar(500,outputname='./simulation_final/data/test/Paravar500.txt',sample_seed=3631270215846359110)
generateparabolavar(300,outputname='./simulation_final/data/test/Paravar300.txt',sample_seed= 5323894522758319255)

# %%
#done
# generatelinearvar(1000,outputname='./simulation_final/data/Linearvar1000.txt')
# generatelinearvar(500,outputname='./simulation_final/data/Linearvar500.txt')
# generatelinearvar(300,outputname='./simulation_final/data/Linearvar300.txt')

# %%
#testing done  # passed 
generatelinearvar(1000,outputname='./simulation_final/data/test/Linearvar1000.txt',sample_seed= 1009939060157602810)
generatelinearvar(500,outputname='./simulation_final/data/test/Linearvar500.txt',sample_seed=3507367129688888920)
generatelinearvar(300,outputname='./simulation_final/data/test/Linearvar300.txt',sample_seed= 2410658795036450850)

# %%
# done 
# generatesine(500,outputname='./simulation_final/data/10rundata/Sine500run1.txt')
# generatesine(500,outputname='./simulation_final/data/10rundata/Sine500run2.txt')
# generatesine(500,outputname='./simulation_final/data/10rundata/Sine500run3.txt')
# generatesine(500,outputname='./simulation_final/data/10rundata/Sine500run4.txt')
# generatesine(500,outputname='./simulation_final/data/10rundata/Sine500run5.txt')
# generatesine(500,outputname='./simulation_final/data/10rundata/Sine500run6.txt')
# generatesine(500,outputname='./simulation_final/data/10rundata/Sine500run7.txt')
# generatesine(500,outputname='./simulation_final/data/10rundata/Sine500run8.txt')
# generatesine(500,outputname='./simulation_final/data/10rundata/Sine500run9.txt')
# generatesine(500,outputname='./simulation_final/data/10rundata/Sine500run10.txt')

# %%
# done
# generatesaw(500,outputname='./simulation_final/data/10rundata/Saw500run1.txt')
# generatesaw(500,outputname='./simulation_final/data/10rundata/Saw500run2.txt')
# generatesaw(500,outputname='./simulation_final/data/10rundata/Saw500run3.txt')
# generatesaw(500,outputname='./simulation_final/data/10rundata/Saw500run4.txt')
# generatesaw(500,outputname='./simulation_final/data/10rundata/Saw500run5.txt')
# generatesaw(500,outputname='./simulation_final/data/10rundata/Saw500run6.txt')
# generatesaw(500,outputname='./simulation_final/data/10rundata/Saw500run7.txt')
# generatesaw(500,outputname='./simulation_final/data/10rundata/Saw500run8.txt')
# generatesaw(500,outputname='./simulation_final/data/10rundata/Saw500run9.txt')
# generatesaw(500,outputname='./simulation_final/data/10rundata/Saw500run10.txt')

# %%
# done
# generateind(500,outputname='./simulation_final/data/10rundata/Indp500run1.txt')
# generateind(500,outputname='./simulation_final/data/10rundata/Indp500run2.txt')
# generateind(500,outputname='./simulation_final/data/10rundata/Indp500run3.txt')
# generateind(500,outputname='./simulation_final/data/10rundata/Indp500run4.txt')
# generateind(500,outputname='./simulation_final/data/10rundata/Indp500run5.txt')
# generateind(500,outputname='./simulation_final/data/10rundata/Indp500run6.txt')
# generateind(500,outputname='./simulation_final/data/10rundata/Indp500run7.txt')
# generateind(500,outputname='./simulation_final/data/10rundata/Indp500run8.txt')
# generateind(500,outputname='./simulation_final/data/10rundata/Indp500run9.txt')
# generateind(500,outputname='./simulation_final/data/10rundata/Indp500run10.txt')

# %%
# done
# generatelinear(500,outputname='./simulation_final/data/10rundata/Linear500run1.txt')
# generatelinear(500,outputname='./simulation_final/data/10rundata/Linear500run2.txt')
# generatelinear(500,outputname='./simulation_final/data/10rundata/Linear500run3.txt')
# generatelinear(500,outputname='./simulation_final/data/10rundata/Linear500run4.txt')
# generatelinear(500,outputname='./simulation_final/data/10rundata/Linear500run5.txt')
# generatelinear(500,outputname='./simulation_final/data/10rundata/Linear500run6.txt')
# generatelinear(500,outputname='./simulation_final/data/10rundata/Linear500run7.txt')
# generatelinear(500,outputname='./simulation_final/data/10rundata/Linear500run8.txt')
# generatelinear(500,outputname='./simulation_final/data/10rundata/Linear500run9.txt')
# generatelinear(500,outputname='./simulation_final/data/10rundata/Linear500run10.txt')

# %%
#not doing testing for the 10 runs because function testing are done
