# %%
import pandas as pd

# %%
df=pd.read_csv("tesr.txt")

# %%
df.head()
# Out:
#    680  0.0  0.0.1  1.0
# 0  681  0.0    0.0  1.0
# 1  682  0.0    0.0  1.0
# 2  683  0.0    0.0  1.0
# 3  684  0.0    0.0  1.0
# 4  685  0.0    0.0  1.0

# %%
df.dtypes
# Out:
# 680        int64
# 0.0      float64
# 0.0.1    float64
# 1.0      float64
# dtype: object

# %%
df.to_csv(header=["datanumber","LA","LB","LBres"])
# Out:
# ',datanumber,LA,LB,LBres\n0,681,0.0,0.0,1.0\n1,682,0.0,0.0,1.0\n2,683,0.0,0.0,1.0\n3,684,0.0,0.0,1.0\n4,685,0.0,0.0,1.0\n5,686,0.0,0.0,1.0\n6,687,0.0,0.0,1.0\n7,688,0.0,0.0,1.0\n8,689,0.0,0.0,0.19\n9,690,0.0,0.0,1.0\n10,691,0.0,0.0,1.0\n11,692,0.0,0.0,1.0\n12,693,0.0,0.0,0.46\n13,694,0.0,0.0,0.0\n14,695,0.0,0.0,1.0\n15,696,0.0,0.0,1.0\n16,697,0.0,0.0,0.17\n17,698,0.0,0.0,1.0\n18,699,0.0,0.0,1.0\n19,580,0.0,0.0,1.0\n20,581,0.0,0.0,1.0\n21,582,0.0,0.0,1.0\n22,583,0.0,0.0,1.0\n23,584,0.0,0.0,1.0\n24,585,0.0,0.0,1.0\n25,586,0.0,0.0,1.0\n26,587,0.0,0.0,1.0\n27,588,0.0,0.0,1.0\n28,589,0.0,0.0,0.45\n29,590,0.0,0.0,0.81\n30,591,0.0,0.0,1.0\n31,592,0.0,0.0,0.32\n32,593,0.0,0.0,0.11\n33,594,0.0,0.0,1.0\n34,595,0.0,0.0,1.0\n35,596,0.0,0.0,1.0\n36,597,0.0,0.0,0.02\n37,598,0.0,0.0,1.0\n38,599,0.0,0.0,1.0\n39,180,0.0,0.0,1.0\n40,181,0.0,0.0,1.0\n41,182,0.0,0.0,1.0\n42,183,0.0,0.0,1.0\n43,184,0.0,0.0,1.0\n44,185,0.0,0.0,1.0\n45,186,0.0,0.0,1.0\n46,187,0.0,0.0,1.0\n47,188,0.0,0.0,1.0\n48,189,0.0,0.0
# ...
